# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cust40078-sudo/flyrank-ml-internship/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# # Basic information
# print("Rows:", df.shape[0])
# print("Columns:", df.shape[1])
#
# df.head()

# %% [markdown]
# # Basic information
# print("Rows:", df.shape[0])
# print("Columns:", df.shape[1])
#
# df.head()

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'sample_data']

# %% [markdown]
# ## Field Classification
#
# ### Features
# Historical search metrics such as clicks, impressions, CTR, position, and other historical measurements.
#
# ### Label
# The target variable that represents the future outcome to be predicted.
#
# ### Context
# Identifiers or descriptive information such as page category, country, or device.
#
# ### Excluded
# Any field containing future information, unique identifiers, URLs, or client-specific information is excluded because it may leak future knowledge into the model.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
import os

print(os.listdir("/content"))
# Out:
# ['.config', 'sample_data']

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
"""
Data Limits

This dataset only contains historical observations.

The analysis cannot prove cause and effect.

Some information may be missing because data collection depends on the available search records.

The results should be used as decision support instead of absolute predictions.

Any future changes in search behaviour cannot be captured by this dataset.
"""
# Out:
# '\nData Limits\n\nThis dataset only contains historical observations.\n\nThe analysis cannot prove cause and effect.\n\nSome information may be missing because data collection depends on the available search records.\n\nThe results should be used as decision support instead of absolute predictions.\n\nAny future changes in search behaviour cannot be captured by this dataset.\n'

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
