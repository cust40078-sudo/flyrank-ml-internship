# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/cust40078-sudo/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# Chosen Lane: Refresh / Content Opportunity Scoring
#
# Why: I selected this lane because our starter repository already includes the content_refresh_anonymized.csv dataset and the starter pipelines. As a software engineer, focusing on data-driven content refresh scoring allows me to immediately work with the existing code infrastructure and help businesses identify which decaying content needs an immediate update to win back lost search traffic.
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# - **Decision:** Which content/pages on the website are currently decaying in performance and should be added to the content refresh queue?
# - **Action:** Content managers and writers will rewrite or update the selected pages based on our prioritized scores.
# - **Cost of a wrong call:** If we recommend a page that doesn't need an update, we waste expensive writing hours. If we miss a high-potential page, we lose organic search traffic and potential revenue to competitors.
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# Real numbers from the FlyRank dataset documentation
total_rows = 519606
total_clients = 104
target_lane = "Refresh / Content Opportunity Scoring"

print(f"1. Total Rows in Warehouse Dataset: {total_rows}")
print(f"2. Total Pseudonymized Clients: {total_clients}")
print(f"3. Target Strategy Selected: {target_lane}")
# Out:
# 1. Total Rows in Warehouse Dataset: 519606
# 2. Total Pseudonymized Clients: 104
# 3. Target Strategy Selected: Refresh / Content Opportunity Scoring

# %% [markdown]
# # Real numbers from the FlyRank dataset documentation
# total_rows = 519606
# total_clients = 104
# target_lane = "Refresh / Content Opportunity Scoring"
#
# print(f"1. Total Rows in Warehouse Dataset: {total_rows}")
# print(f"2. Total Pseudonymized Clients: {total_clients}")
# print(f"3. Target Strategy Selected: {target_lane}")
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# # Section 4 - Careful words written as a Python comment
# # CAN CLAIM: Decision-support rankings based on observed historical performance.
# # CANNOT CLAIM: Causal proof or predicting Google's internal algorithm updates.
# print("Section 4 text successfully saved as code comments.")
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
